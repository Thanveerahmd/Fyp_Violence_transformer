# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanveerahmd/Fyp_Violence_transformer/blob/main/RLVS_video_transformers_40_bi_trans_with__classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/Final_Year_Project/Dataset/RLVS/real_life_violence_situations
# Out:
# /content/gdrive/MyDrive/Final_Year_Project/Dataset/RLVS/real_life_violence_situations

# %%
ls
# Out:
#  animation.gif                  rlvs_train_data_40.npy
# 'Real Life Violence Dataset'/   rlvs_train_data.npy
#  rlvs/                          rlvs_train_labels_40.npy
#  rlvs_test_data_40.npy          rlvs_train_labels.npy
#  rlvs_test_data.npy             rlvs_train.txt
#  rlvs_test_labels_40.npy        test.csv
#  rlvs_test_labels.npy           train.csv
#  rlvs_test.txt

# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %% [markdown]
# ## Setup

# %%
from tensorflow_docs.vis import embed
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2
import os

# %% [markdown]
# ## Define hyperparameters

# %%
MAX_SEQ_LENGTH = 40
NUM_FEATURES = 1024
IMG_SIZE = 176

EPOCHS = 50

# %% [markdown]
# ## Data preparation
#
# We will mostly be following the same data preparation steps in this example, except for
# the following changes:
#
# * We reduce the image size to 128x128 instead of 224x224 to speed up computation.
# * Instead of using a pre-trained [InceptionV3](https://arxiv.org/abs/1512.00567) network,
# we use a pre-trained
# [DenseNet121](http://openaccess.thecvf.com/content_cvpr_2017/papers/Huang_Densely_Connected_Convolutional_CVPR_2017_paper.pdf)
# for feature extraction.
# * We directly pad shorter videos to length `MAX_SEQ_LENGTH`.
#
# First, let's load up the
# [DataFrames](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html).

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

print(f"Total videos for training: {len(train_df)}")
print(f"Total videos for testing: {len(test_df)}")

center_crop_layer = layers.CenterCrop(IMG_SIZE, IMG_SIZE)


def crop_center(frame):
    cropped = center_crop_layer(frame[None, ...])
    cropped = cropped.numpy().squeeze()
    return cropped


# Following method is modified from this tutorial:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def load_video(path, max_frames=0):

    cap = cv2.VideoCapture(path)

    width  = cap.get(3)  # float `width`
    height = cap.get(4)  # float `height`
    print('width, height:', width, height)

    frames = []
    try:
        while True:

            ret, frame = cap.read()
            if not ret:
                break
            #frame = crop_center(frame)
            frame = cv2.resize(frame, (IMG_SIZE, IMG_SIZE))
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)


def build_feature_extractor():
    feature_extractor = keras.applications.DenseNet121(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.densenet.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()


# Label preprocessing with StringLookup.
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"]), mask_token=None
)
print(label_processor.get_vocabulary())


def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = df["tag"].values
    labels = label_processor(labels[..., None]).numpy()

    # `frame_features` are what we will feed to our sequence model.
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for idx, path in enumerate(video_paths):
        # Gather all its frames and add a batch dimension.
        frames = load_video(os.path.join(root_dir, path))

        #print(path)
        print(frames.shape)

        # Pad shorter videos.
        if len(frames) < MAX_SEQ_LENGTH:
            diff = MAX_SEQ_LENGTH - len(frames)
            padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
            frames = np.concatenate(frames, padding)

        frames = frames[None, ...]

        # Initialize placeholder to store the features of the current video.
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                if np.mean(batch[j, :]) > 0.0:
                    temp_frame_features[i, j, :] = feature_extractor.predict(
                        batch[None, j, :]
                    )

                else:
                    temp_frame_features[i, j, :] = 0.0

        frame_features[idx,] = temp_frame_features.squeeze()

    return frame_features, labels
# Out:
# Total videos for training: 1600
# Total videos for testing: 400
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 1s 0us/step
# 29097984/29084464 [==============================] - 1s 0us/step
# ['NonViolence', 'Violence']

# %%
train_data, train_labels = prepare_all_videos(train_df, "rlvs/train")
test_data, test_labels = prepare_all_videos(test_df, "rlvs/test")

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in test set: {test_data[1].shape}")

# %%
from numpy import save

save('rlvs_train_data.npy', train_data)
save('rlvs_train_labels.npy', train_labels)
save('rlvs_test_data.npy', test_data)
save('rlvs_test_labels.npy', test_labels)

# %%
train_data, train_labels = np.load("rlvs_train_data_40.npy"), np.load("rlvs_train_labels_40.npy")
test_data, test_labels = np.load("rlvs_test_data_40.npy"), np.load("rlvs_test_labels_40.npy")

# %%
print(f"Frame features in train set: {train_data.shape}")
print(f"Frame features in train label set: {train_labels.shape}")
print(f"Frame features in test set: {test_data.shape}")
print(f"Frame features in test label set: {test_labels.shape}")
# Out:
# Frame features in train set: (1600, 40, 1024)
# Frame features in train label set: (1600, 1)
# Frame features in test set: (400, 40, 1024)
# Frame features in test label set: (400, 1)

# %% [markdown]
# Calling `prepare_all_videos()` on `train_df` and `test_df` takes ~20 minutes to
# complete. For this reason, to save time, here we download already preprocessed NumPy arrays:

# %% [markdown]
# ## Building the Transformer-based model
#
# We will be building on top of the code shared in
# [this book chapter](https://livebook.manning.com/book/deep-learning-with-python-second-edition/chapter-11) of
# [Deep Learning with Python (Second ed.)](https://www.manning.com/books/deep-learning-with-python)
# by François Chollet.
#
# First, self-attention layers that form the basic blocks of a Transformer are
# order-agnostic. Since videos are ordered sequences of frames, we need our
# Transformer model to take into account order information.
# We do this via **positional encoding**.
# We simply embed the positions of the frames present inside videos with an
# [`Embedding` layer](https://keras.io/api/layers/core_layers/embedding). We then
# add these positional embeddings to the precomputed CNN feature maps.

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %% [markdown]
# Now, we can create a subclassed layer for the Transformer.

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
def get_compiled_model():
    sequence_length = MAX_SEQ_LENGTH
    embed_dim = NUM_FEATURES
    dense_dim = 64
    num_heads = 8
    classes = len(label_processor.get_vocabulary())

    inputs = keras.Input(shape=(None, None))
    x = PositionalEmbedding(
        sequence_length, embed_dim, name="frame_position_embedding"
    )(inputs)
    x = layers.Bidirectional(layers.LSTM(embed_dim,return_sequences=True))(x)
    x = TransformerEncoder(2*embed_dim, dense_dim, num_heads, name="transformer_layer_1")(x)
    #x = TransformerEncoder(2*embed_dim, dense_dim, num_heads, name="transformer_layer_2")(x)
    #x = layers.Bidirectional(layers.LSTM(1024,return_sequences=True))(x)
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(1024)(x)
    x = layers.Dropout(0.25)(x)
    x = layers.Dense(128)(x)
    x = layers.Dropout(0.25)(x)
    x = layers.Dense(16)(x)
    x = layers.Dropout(0.25)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)
    model = keras.Model(inputs, outputs)

    model.compile(
        optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
model = get_compiled_model()

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, None, None)]      0
# _________________________________________________________________
# frame_position_embedding (Po (None, None, 1024)        40960
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, None, 2048)        16785408
# _________________________________________________________________
# transformer_layer_1 (Transfo (None, None, 2048)        134541376
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 2048)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 153,599,201
# Trainable params: 153,599,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Utility functions for training

# %%
def run_experiment():
    filepath = "/tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    
    history = model.fit(
        train_data,
        train_labels,
        validation_split=0.15,
        epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    model.load_weights(filepath)
    _, accuracy = model.evaluate(test_data, test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return model,history

# %% [markdown]
# ## Model training and inference

# %%
trained_model,history = run_experiment()
# Out:
# Epoch 1/50
# 43/43 [==============================] - 49s 806ms/step - loss: 8.5006 - accuracy: 0.5316 - val_loss: 4.6629 - val_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 4.66286, saving model to /tmp/video_classifier
# Epoch 2/50
# 43/43 [==============================] - 32s 744ms/step - loss: 3.5667 - accuracy: 0.5353 - val_loss: 4.7762 - val_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 4.66286
# Epoch 3/50
# 43/43 [==============================] - 32s 755ms/step - loss: 3.3243 - accuracy: 0.5287 - val_loss: 1.8980 - val_accuracy: 0.0000e+00
#
# Epoch 00003: val_loss improved from 4.66286 to 1.89799, saving model to /tmp/video_classifier
# Epoch 4/50
# 43/43 [==============================] - 32s 754ms/step - loss: 2.4646 - accuracy: 0.5007 - val_loss: 1.2032 - val_accuracy: 0.0000e+00
#
# Epoch 00004: val_loss improved from 1.89799 to 1.20323, saving model to /tmp/video_classifier
# Epoch 5/50
# 43/43 [==============================] - 33s 758ms/step - loss: 1.7741 - accuracy: 0.5125 - val_loss: 1.7992 - val_accuracy: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 1.20323
# Epoch 6/50
# 43/43 [==============================] - 32s 755ms/step - loss: 1.5068 - accuracy: 0.5324 - val_loss: 0.9470 - val_accuracy: 0.0000e+00
#
# Epoch 00006: val_loss improved from 1.20323 to 0.94700, saving model to /tmp/video_classifier
# Epoch 7/50
# 43/43 [==============================] - 32s 750ms/step - loss: 1.3395 - accuracy: 0.5169 - val_loss: 1.5570 - val_accuracy: 0.0000e+00
#
# Epoch 00007: val_loss did not improve from 0.94700
# Epoch 8/50
# 43/43 [==============================] - 32s 748ms/step - loss: 1.2365 - accuracy: 0.5272 - val_loss: 0.7991 - val_accuracy: 0.0000e+00
#
# Epoch 00008: val_loss improved from 0.94700 to 0.79906, saving model to /tmp/video_classifier
# Epoch 9/50
# 43/43 [==============================] - 32s 742ms/step - loss: 1.1578 - accuracy: 0.5243 - val_loss: 1.7884 - val_accuracy: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 0.79906
# Epoch 10/50
# 43/43 [==============================] - 32s 742ms/step - loss: 1.1121 - accuracy: 0.4956 - val_loss: 0.9444 - val_accuracy: 0.0000e+00
#
# Epoch 00010: val_loss did not improve from 0.79906
# Epoch 11/50
# 43/43 [==============================] - 32s 742ms/step - loss: 1.0718 - accuracy: 0.5125 - val_loss: 1.2361 - val_accuracy: 0.0000e+00
#
# Epoch 00011: val_loss did not improve from 0.79906
# Epoch 12/50
# 43/43 [==============================] - 32s 741ms/step - loss: 0.9424 - accuracy: 0.5375 - val_loss: 0.5159 - val_accuracy: 1.0000
#
# Epoch 00012: val_loss improved from 0.79906 to 0.51587, saving model to /tmp/video_classifier
# Epoch 13/50
# 43/43 [==============================] - 32s 735ms/step - loss: 0.8853 - accuracy: 0.5213 - val_loss: 1.3230 - val_accuracy: 0.0000e+00
#
# Epoch 00013: val_loss did not improve from 0.51587
# Epoch 14/50
# 43/43 [==============================] - 32s 736ms/step - loss: 0.9131 - accuracy: 0.5162 - val_loss: 1.0751 - val_accuracy: 0.0000e+00
#
# Epoch 00014: val_loss did not improve from 0.51587
# Epoch 15/50
# 43/43 [==============================] - 32s 739ms/step - loss: 0.8890 - accuracy: 0.5147 - val_loss: 0.8480 - val_accuracy: 0.0000e+00
#
# Epoch 00015: val_loss did not improve from 0.51587
# Epoch 16/50
# 43/43 [==============================] - 31s 731ms/step - loss: 0.8560 - accuracy: 0.5272 - val_loss: 0.9048 - val_accuracy: 0.0000e+00
#
# Epoch 00016: val_loss did not improve from 0.51587
# Epoch 17/50
# 43/43 [==============================] - 31s 726ms/step - loss: 0.8215 - accuracy: 0.5279 - val_loss: 1.2924 - val_accuracy: 0.0000e+00
#
# Epoch 00017: val_loss did not improve from 0.51587
# Epoch 18/50
# 43/43 [==============================] - 31s 722ms/step - loss: 0.8346 - accuracy: 0.5390 - val_loss: 1.1358 - val_accuracy: 0.0000e+00
#
# Epoch 00018: val_loss did not improve from 0.51587
# Epoch 19/50
# 43/43 [==============================] - 31s 722ms/step - loss: 0.7948 - accuracy: 0.5515 - val_loss: 0.8300 - val_accuracy: 0.0000e+00
#
# Epoch 00019: val_loss did not improve from 0.51587
# Epoch 20/50
# 43/43 [==============================] - 31s 726ms/step - loss: 0.7914 - accuracy: 0.5272 - val_loss: 0.8590 - val_accuracy: 0.0000e+00
#
# Epoch 00020: val_loss did not improve from 0.51587
# Epoch 21/50
# 43/43 [==============================] - 31s 714ms/step - loss: 0.7177 - accuracy: 0.6125 - val_loss: 0.7785 - val_accuracy: 0.6125
#
# Epoch 00021: val_loss did not improve from 0.51587
# Epoch 22/50
# 43/43 [==============================] - 31s 730ms/step - loss: 0.4331 - accuracy: 0.8316 - val_loss: 0.3270 - val_accuracy: 0.8458
#
# Epoch 00022: val_loss improved from 0.51587 to 0.32696, saving model to /tmp/video_classifier
# Epoch 23/50
# 43/43 [==============================] - 31s 722ms/step - loss: 0.3255 - accuracy: 0.8904 - val_loss: 0.6712 - val_accuracy: 0.7417
#
# Epoch 00023: val_loss did not improve from 0.32696
# Epoch 24/50
# 43/43 [==============================] - 31s 725ms/step - loss: 0.2990 - accuracy: 0.8846 - val_loss: 0.9945 - val_accuracy: 0.6125
#
# Epoch 00024: val_loss did not improve from 0.32696
# Epoch 25/50
# 43/43 [==============================] - 31s 727ms/step - loss: 0.2272 - accuracy: 0.9191 - val_loss: 0.6426 - val_accuracy: 0.7667
#
# Epoch 00025: val_loss did not improve from 0.32696
# Epoch 26/50
# 43/43 [==============================] - 31s 729ms/step - loss: 0.1894 - accuracy: 0.9309 - val_loss: 0.2366 - val_accuracy: 0.9042
#
# Epoch 00026: val_loss improved from 0.32696 to 0.23660, saving model to /tmp/video_classifier
# Epoch 27/50
# 43/43 [==============================] - 31s 727ms/step - loss: 0.1704 - accuracy: 0.9360 - val_loss: 0.2607 - val_accuracy: 0.8917
#
# Epoch 00027: val_loss did not improve from 0.23660
# Epoch 28/50
# 43/43 [==============================] - 32s 736ms/step - loss: 0.1352 - accuracy: 0.9566 - val_loss: 0.5668 - val_accuracy: 0.8417
#
# Epoch 00028: val_loss did not improve from 0.23660
# Epoch 29/50
# 43/43 [==============================] - 32s 741ms/step - loss: 0.1257 - accuracy: 0.9618 - val_loss: 0.2984 - val_accuracy: 0.8917
#
# Epoch 00029: val_loss did not improve from 0.23660
# Epoch 30/50
# 43/43 [==============================] - 32s 736ms/step - loss: 0.0887 - accuracy: 0.9669 - val_loss: 0.6508 - val_accuracy: 0.8125
#
# Epoch 00030: val_loss did not improve from 0.23660
# Epoch 31/50
# 43/43 [==============================] - 32s 738ms/step - loss: 0.0628 - accuracy: 0.9809 - val_loss: 0.5813 - val_accuracy: 0.8167
#
# Epoch 00031: val_loss did not improve from 0.23660
# Epoch 32/50
# 43/43 [==============================] - 32s 742ms/step - loss: 0.0477 - accuracy: 0.9824 - val_loss: 1.3595 - val_accuracy: 0.7208
#
# Epoch 00032: val_loss did not improve from 0.23660
# Epoch 33/50
# 43/43 [==============================] - 32s 743ms/step - loss: 0.0762 - accuracy: 0.9721 - val_loss: 0.6015 - val_accuracy: 0.8500
#
# Epoch 00033: val_loss did not improve from 0.23660
# Epoch 34/50
# 43/43 [==============================] - 32s 744ms/step - loss: 0.1494 - accuracy: 0.9471 - val_loss: 0.1424 - val_accuracy: 0.9542
#
# Epoch 00034: val_loss improved from 0.23660 to 0.14237, saving model to /tmp/video_classifier
# Epoch 35/50
# 43/43 [==============================] - 32s 735ms/step - loss: 0.0681 - accuracy: 0.9787 - val_loss: 0.3219 - val_accuracy: 0.9208
#
# Epoch 00035: val_loss did not improve from 0.14237
# Epoch 36/50
# 43/43 [==============================] - 32s 736ms/step - loss: 0.0323 - accuracy: 0.9919 - val_loss: 0.7838 - val_accuracy: 0.8250
#
# Epoch 00036: val_loss did not improve from 0.14237
# Epoch 37/50
# 43/43 [==============================] - 32s 738ms/step - loss: 0.0381 - accuracy: 0.9868 - val_loss: 0.7165 - val_accuracy: 0.8375
#
# Epoch 00037: val_loss did not improve from 0.14237
# Epoch 38/50
# 43/43 [==============================] - 32s 739ms/step - loss: 0.0197 - accuracy: 0.9941 - val_loss: 1.5755 - val_accuracy: 0.7250
#
# Epoch 00038: val_loss did not improve from 0.14237
# Epoch 39/50
# 43/43 [==============================] - 32s 737ms/step - loss: 0.0307 - accuracy: 0.9904 - val_loss: 0.7400 - val_accuracy: 0.8625
#
# Epoch 00039: val_loss did not improve from 0.14237
# Epoch 40/50
# 43/43 [==============================] - 32s 739ms/step - loss: 0.0332 - accuracy: 0.9912 - val_loss: 0.5410 - val_accuracy: 0.8792
#
# Epoch 00040: val_loss did not improve from 0.14237
# Epoch 41/50
# 43/43 [==============================] - 32s 736ms/step - loss: 0.0152 - accuracy: 0.9971 - val_loss: 0.8506 - val_accuracy: 0.8500
#
# Epoch 00041: val_loss did not improve from 0.14237
# Epoch 42/50
# 43/43 [==============================] - 31s 729ms/step - loss: 0.0465 - accuracy: 0.9890 - val_loss: 1.8742 - val_accuracy: 0.6958
#
# Epoch 00042: val_loss did not improve from 0.14237
# Epoch 43/50
# 43/43 [==============================] - 32s 731ms/step - loss: 0.0468 - accuracy: 0.9772 - val_loss: 1.5706 - val_accuracy: 0.7750
#
# Epoch 00043: val_loss did not improve from 0.14237
# Epoch 44/50
# 43/43 [==============================] - 32s 740ms/step - loss: 0.0749 - accuracy: 0.9794 - val_loss: 0.2916 - val_accuracy: 0.9208
#
# Epoch 00044: val_loss did not improve from 0.14237
# Epoch 45/50
# 43/43 [==============================] - 32s 741ms/step - loss: 0.0213 - accuracy: 0.9912 - val_loss: 0.4325 - val_accuracy: 0.9250
#
# Epoch 00045: val_loss did not improve from 0.14237
# Epoch 46/50
# 43/43 [==============================] - 32s 741ms/step - loss: 0.0056 - accuracy: 0.9971 - val_loss: 1.7054 - val_accuracy: 0.8083
#
# Epoch 00046: val_loss did not improve from 0.14237
# Epoch 47/50
# 43/43 [==============================] - 32s 740ms/step - loss: 0.0210 - accuracy: 0.9941 - val_loss: 0.7247 - val_accuracy: 0.9125
#
# Epoch 00047: val_loss did not improve from 0.14237
# Epoch 48/50
# 43/43 [==============================] - 32s 740ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 1.1071 - val_accuracy: 0.8792
#
# Epoch 00048: val_loss did not improve from 0.14237
# Epoch 49/50
# 43/43 [==============================] - 32s 737ms/step - loss: 0.0207 - accuracy: 0.9949 - val_loss: 1.1531 - val_accuracy: 0.8458
#
# Epoch 00049: val_loss did not improve from 0.14237
# Epoch 50/50
# 43/43 [==============================] - 32s 743ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 1.6564 - val_accuracy: 0.7875
#
# Epoch 00050: val_loss did not improve from 0.14237
# 13/13 [==============================] - 3s 227ms/step - loss: 0.2060 - accuracy: 0.9525
# Test accuracy: 95.25%

# %%
from matplotlib import pyplot

# %%
    pyplot.title('Learning Curves')
    pyplot.xlabel('Epoch')
    pyplot.ylabel('Root Mean Squared Error')
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='val')
    pyplot.legend()
    pyplot.show()

# %%
    pyplot.title('Learning Curves')
    pyplot.xlabel('Epoch')
    pyplot.ylabel('accuracy')
    pyplot.plot(history.history['accuracy'], label='train')
    pyplot.plot(history.history['val_accuracy'], label='val')
    pyplot.legend()
    pyplot.show()

# %% [markdown]
# **Note**: This model has ~4.23 Million parameters, which is way more than the sequence
# model (99918 parameters) we used in the prequel of this example.  This kind of
# Transformer model works best with a larger dataset and a longer pre-training schedule.

# %%
def prepare_single_video(frames):
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    # Pad shorter videos.
    if len(frames) < MAX_SEQ_LENGTH:
        diff = MAX_SEQ_LENGTH - len(frames)
        padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
        frames = np.concatenate(frames, padding)

    frames = frames[None, ...]

    # Extract features from the frames of the current video.
    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            if np.mean(batch[j, :]) > 0.0:
                frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
            else:
                frame_features[i, j, :] = 0.0

    return frame_features


def predict_action(path):
    class_vocab = label_processor.get_vocabulary()

    frames = load_video(os.path.join("rlvs/test/", path))
    frame_features = prepare_single_video(frames)
    probabilities = trained_model.predict(frame_features)[0]

    for i in np.argsort(probabilities)[::-1]:
        print(f"  {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")
    return frames


# This utility is for visualization.
# Referenced from:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def to_gif(images):
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, fps=10)
    return embed.embed_file("animation.gif")


test_video = np.random.choice(test_df["video_name"].values.tolist())
print(f"Test video path: {test_video}")
test_frames = predict_action(test_video)
to_gif(test_frames[:MAX_SEQ_LENGTH])
# Out:
# Test video path: NonViolence/NV_689.mp4
# width, height: 224.0 224.0
#   NonViolence:  0.44%
# <img src="data:image/gif;base64,..."/>

# %% [markdown]
# The performance of our model is far from optimal, because it was trained on a
# small dataset.
