# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanveerahmd/Fyp_Violence_transformer/blob/main/RLVS_video_transformers_20_frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/Final_Year_Project/Dataset/RLVS/real_life_violence_situations
# Out:
# /content/gdrive/MyDrive/Final_Year_Project/Dataset/RLVS/real_life_violence_situations

# %%
ls
# Out:
# 'Real Life Violence Dataset'/   rlvs_test.txt           test.csv
#  rlvs/                          rlvs_train_data.npy     train.csv
#  rlvs_test_data.npy             rlvs_train_labels.npy
#  rlvs_test_labels.npy           rlvs_train.txt

# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %% [markdown]
# ## Setup

# %%
from tensorflow_docs.vis import embed
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2
import os

# %% [markdown]
# ## Define hyperparameters

# %%
MAX_SEQ_LENGTH = 20
NUM_FEATURES = 1024
IMG_SIZE = 176

EPOCHS = 100

# %% [markdown]
# ## Data preparation
#
# We will mostly be following the same data preparation steps in this example, except for
# the following changes:
#
# * We reduce the image size to 128x128 instead of 224x224 to speed up computation.
# * Instead of using a pre-trained [InceptionV3](https://arxiv.org/abs/1512.00567) network,
# we use a pre-trained
# [DenseNet121](http://openaccess.thecvf.com/content_cvpr_2017/papers/Huang_Densely_Connected_Convolutional_CVPR_2017_paper.pdf)
# for feature extraction.
# * We directly pad shorter videos to length `MAX_SEQ_LENGTH`.
#
# First, let's load up the
# [DataFrames](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html).

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

print(f"Total videos for training: {len(train_df)}")
print(f"Total videos for testing: {len(test_df)}")

center_crop_layer = layers.CenterCrop(IMG_SIZE, IMG_SIZE)


def crop_center(frame):
    cropped = center_crop_layer(frame[None, ...])
    cropped = cropped.numpy().squeeze()
    return cropped


# Following method is modified from this tutorial:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def load_video(path, max_frames=0):

    cap = cv2.VideoCapture(path)

    width  = cap.get(3)  # float `width`
    height = cap.get(4)  # float `height`
    print('width, height:', width, height)

    frames = []
    try:
        while True:

            ret, frame = cap.read()
            if not ret:
                break
            #frame = crop_center(frame)
            frame = cv2.resize(frame, (IMG_SIZE, IMG_SIZE))
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)


def build_feature_extractor():
    feature_extractor = keras.applications.DenseNet121(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.densenet.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()


# Label preprocessing with StringLookup.
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"]), mask_token=None
)
print(label_processor.get_vocabulary())


def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = df["tag"].values
    labels = label_processor(labels[..., None]).numpy()

    # `frame_features` are what we will feed to our sequence model.
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for idx, path in enumerate(video_paths):
        # Gather all its frames and add a batch dimension.
        frames = load_video(os.path.join(root_dir, path))

        print(path)
        print(frames.shape)

        # Pad shorter videos.
        if len(frames) < MAX_SEQ_LENGTH:
            diff = MAX_SEQ_LENGTH - len(frames)
            padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
            frames = np.concatenate(frames, padding)

        frames = frames[None, ...]

        # Initialize placeholder to store the features of the current video.
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                if np.mean(batch[j, :]) > 0.0:
                    temp_frame_features[i, j, :] = feature_extractor.predict(
                        batch[None, j, :]
                    )

                else:
                    temp_frame_features[i, j, :] = 0.0

        frame_features[idx,] = temp_frame_features.squeeze()

    return frame_features, labels
# Out:
# Total videos for training: 1600
# Total videos for testing: 400
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# ['NonViolence', 'Violence']

# %%
train_data, train_labels = prepare_all_videos(train_df, "rlvs/train")
test_data, test_labels = prepare_all_videos(test_df, "rlvs/test")

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in test set: {test_data[1].shape}")
# Out:
# Streaming output truncated to the last 5000 lines.
# width, height: 224.0 224.0
# NonViolence/NV_922.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_993.mp4
# (135, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_472.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_634.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_330.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_380.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_467.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_244.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_372.mp4
# (55, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_356.mp4
# (104, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_679.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_670.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_416.mp4
# (55, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_16.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_709.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_849.mp4
# (110, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_940.mp4
# (29, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_71.mp4
# (150, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_746.mp4
# (144, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_311.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_337.mp4
# (110, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_18.mp4
# (144, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_850.mp4
# (124, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_875.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_147.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_690.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_948.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_464.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_440.mp4
# (55, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_21.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_540.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_820.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_909.avi
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_486.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_95.mp4
# (120, 176, 176, 3)
# width, height: 368.0 272.0
# NonViolence/NV_731.mp4
# (177, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_363.mp4
# (128, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_89.mp4
# (138, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_29.mp4
# (123, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_925.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_131.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_873.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_907.avi
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_210.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_119.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_854.mp4
# (113, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_978.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_19.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_201.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_490.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_954.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_206.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_444.mp4
# (55, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_140.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_252.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_384.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_390.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_891.avi
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_335.mp4
# (110, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_229.mp4
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_137.mp4
# (108, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_552.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_176.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_437.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_576.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_985.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_865.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_409.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_461.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_301.mp4
# (174, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_988.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_246.mp4
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_40.mp4
# (133, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_639.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_923.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_523.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_500.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_195.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_87.mp4
# (126, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_238.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_510.mp4
# (145, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_350.mp4
# (159, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_285.mp4
# (110, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_237.mp4
# (128, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_627.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_780.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_986.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_443.mp4
# (55, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_82.mp4
# (103, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_682.mp4
# (120, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_824.mp4
# (147, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_581.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_551.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_762.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_601.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_589.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_419.mp4
# (55, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_284.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_899.avi
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_649.mp4
# (145, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_739.mp4
# (158, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_577.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_331.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_236.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_866.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_155.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_49.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_403.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_560.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_772.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_537.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_570.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_902.avi
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_956.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_266.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_704.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_407.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_438.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_911.mp4
# (145, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_43.mp4
# (118, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_61.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_346.mp4
# (153, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_72.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_338.mp4
# (180, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_802.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_942.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_579.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_118.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_587.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_186.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_364.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_512.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_276.mp4
# (125, 176, 176, 3)
# width, height: 368.0 272.0
# NonViolence/NV_735.mp4
# (171, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_333.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_378.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_980.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_242.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_460.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_584.mp4
# (115, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_257.mp4
# (161, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_752.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_812.mp4
# (115, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_835.mp4
# (139, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_8.mp4
# (128, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_78.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_366.mp4
# (55, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_180.mp4
# (108, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_935.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_502.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_68.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_110.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_530.mp4
# (115, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_996.mp4
# (154, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_880.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_487.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_724.mp4
# (148, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_550.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_332.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_394.mp4
# (55, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_26.mp4
# (129, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_606.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_454.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_544.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_13.mp4
# (155, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_497.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_933.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_692.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_671.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_187.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_401.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_109.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_714.mp4
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_202.mp4
# (113, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_50.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_465.mp4
# (115, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_832.mp4
# (134, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_38.mp4
# (132, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_420.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_522.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_282.mp4
# (100, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_302.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_531.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_133.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_450.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_198.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_848.mp4
# (103, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_83.mp4
# (95, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_965.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_478.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_404.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_263.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_997.mp4
# (152, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_479.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_261.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_912.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_874.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_683.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_77.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_729.mp4
# (135, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_193.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_926.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_685.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_428.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_656.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_913.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_382.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_136.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_215.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_495.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_234.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_628.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_130.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_235.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_707.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_963.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_64.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_492.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_505.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_805.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_34.mp4
# (133, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_218.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_405.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_821.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_139.mp4
# (113, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_353.mp4
# (119, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_686.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_952.mp4
# (145, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_145.mp4
# (125, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_838.mp4
# (109, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_80.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_979.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_638.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_286.mp4
# (163, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_414.mp4
# (55, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_292.mp4
# (108, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_358.mp4
# (78, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_349.mp4
# (147, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_957.mp4
# (145, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_837.mp4
# (127, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_197.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_204.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_946.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_221.mp4
# (125, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_194.mp4
# (95, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_374.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_974.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_105.mp4
# (125, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_839.mp4
# (162, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_377.mp4
# (55, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_6.mp4
# (103, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_768.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_67.mp4
# (150, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_360.mp4
# (133, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_439.mp4
# (55, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_9.mp4
# (123, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_665.mp4
# (120, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_42.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_74.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_657.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_565.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_695.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_594.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_166.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_190.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_617.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_870.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_106.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_165.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_955.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_52.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_375.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_219.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_872.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_895.avi
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_318.mp4
# (103, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_676.mp4
# (120, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_287.mp4
# (110, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_339.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_882.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_580.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_619.mp4
# (105, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_86.mp4
# (129, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_970.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_173.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_134.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_646.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_631.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_867.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_623.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_208.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_470.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_314.mp4
# (129, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_75.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_647.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_789.mp4
# (115, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_27.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_172.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_567.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_888.avi
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_823.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_803.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_561.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_538.mp4
# (115, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_861.mp4
# (110, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_703.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_150.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_388.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_720.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_599.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_632.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_852.mp4
# (87, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_299.mp4
# (135, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_371.mp4
# (55, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_743.mp4
# (140, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_240.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_547.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_610.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_906.avi
# (150, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_361.mp4
# (124, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_517.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_989.mp4
# (146, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_458.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_100.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_897.avi
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_25.mp4
# (129, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_751.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_881.avi
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_295.mp4
# (132, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_541.mp4
# (145, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_742.mp4
# (164, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_775.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_251.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_316.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_981.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_111.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_597.mp4
# (105, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_7.mp4
# (95, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_144.mp4
# (113, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_99.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_605.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_506.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_168.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_328.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_92.mp4
# (133, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_744.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_267.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_845.mp4
# (113, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_227.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_969.mp4
# (145, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_831.mp4
# (135, 176, 176, 3)
# width, height: 368.0 272.0
# NonViolence/NV_733.mp4
# (180, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_93.mp4
# (108, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_327.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_199.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_410.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_47.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_154.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_189.mp4
# (50, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_694.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_700.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_719.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_148.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_529.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_477.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_779.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_424.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_496.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_705.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_950.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_185.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_273.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_473.mp4
# (115, 176, 176, 3)
# width, height: 368.0 272.0
# NonViolence/NV_737.mp4
# (147, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_321.mp4
# (93, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_534.mp4
# (145, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_63.mp4
# (88, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_624.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_22.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_777.mp4
# (115, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_296.mp4
# (123, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_79.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_715.mp4
# (125, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_355.mp4
# (73, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_317.mp4
# (110, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_572.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_754.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_402.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_884.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_160.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_886.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_152.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_680.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_750.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_163.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_104.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_97.mp4
# (88, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_76.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_31.mp4
# (123, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_609.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_640.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_117.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_41.mp4
# (123, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_843.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_305.mp4
# (168, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_326.mp4
# (118, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_209.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_514.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_575.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_501.mp4
# (145, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_847.mp4
# (113, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_973.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_717.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_859.mp4
# (107, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_386.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_756.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_283.mp4
# (93, 176, 176, 3)
# width, height: 368.0 272.0
# NonViolence/NV_734.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_943.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_804.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_879.avi
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_489.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_658.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_585.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_869.avi
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_250.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_604.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_536.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_706.mp4
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_216.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_213.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_59.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_161.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_546.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_773.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_177.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_939.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_878.avi
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_32.mp4
# (126, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_151.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_319.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_381.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_432.mp4
# (55, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_826.mp4
# (137, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_115.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_549.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_397.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_650.mp4
# (145, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_1.mp4
# (66, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_588.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_596.mp4
# (105, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_247.mp4
# (135, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_817.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_442.mp4
# (55, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_85.mp4
# (95, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_975.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_903.avi
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_815.mp4
# (115, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_999.mp4
# (168, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_373.mp4
# (55, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_675.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_196.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_566.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_262.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_800.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_56.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 546.0
# Violence/V_798.mp4
# (124, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_555.mp4
# (185, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_904.mp4
# (165, 176, 176, 3)
# width, height: 198.0 360.0
# Violence/V_929.mp4
# (153, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_128.mp4
# (177, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_533.mp4
# (185, 176, 176, 3)
# width, height: 204.0 360.0
# Violence/V_175.mp4
# (123, 176, 176, 3)
# width, height: 724.0 668.0
# Violence/V_774.mp4
# (144, 176, 176, 3)
# width, height: 640.0 352.0
# Violence/V_417.mp4
# (126, 176, 176, 3)
# width, height: 406.0 514.0
# Violence/V_57.mp4
# (90, 176, 176, 3)
# width, height: 398.0 720.0
# Violence/V_264.mp4
# (159, 176, 176, 3)
# width, height: 416.0 548.0
# Violence/V_827.mp4
# (144, 176, 176, 3)
# width, height: 396.0 720.0
# Violence/V_475.mp4
# (141, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_652.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_712.mp4
# (125, 176, 176, 3)
# width, height: 162.0 350.0
# Violence/V_55.mp4
# (156, 176, 176, 3)
# width, height: 716.0 720.0
# Violence/V_783.mp4
# (138, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_142.mp4
# (177, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_758.mp4
# (132, 176, 176, 3)
# width, height: 1280.0 434.0
# Violence/V_400.mp4
# (129, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_503.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_81.mp4
# (153, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_413.mp4
# (117, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_519.mp4
# (123, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_659.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_527.mp4
# (185, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_651.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_598.mp4
# (185, 176, 176, 3)
# width, height: 632.0 466.0
# Violence/V_427.mp4
# (141, 176, 176, 3)
# width, height: 400.0 546.0
# Violence/V_792.mp4
# (122, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_666.mp4
# (125, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_945.mp4
# (135, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_816.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_545.mp4
# (185, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_930.mp4
# (189, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_430.mp4
# (132, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_635.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_747.mp4
# (135, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_146.mp4
# (177, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_482.mp4
# (144, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_149.mp4
# (177, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_336.mp4
# (165, 176, 176, 3)
# width, height: 1280.0 546.0
# Violence/V_794.mp4
# (107, 176, 176, 3)
# width, height: 428.0 720.0
# Violence/V_265.mp4
# (129, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_518.mp4
# (138, 176, 176, 3)
# width, height: 406.0 614.0
# Violence/V_809.mp4
# (153, 176, 176, 3)
# width, height: 314.0 720.0
# Violence/V_255.mp4
# (156, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_233.mp4
# (153, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_766.mp4
# (123, 176, 176, 3)
# width, height: 1038.0 720.0
# Violence/V_20.mp4
# (147, 176, 176, 3)
# width, height: 428.0 606.0
# Violence/V_484.mp4
# (147, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_968.mp4
# (153, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_114.mp4
# (150, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_269.mp4
# (147, 176, 176, 3)
# width, height: 396.0 720.0
# Violence/V_471.mp4
# (120, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_629.mp4
# (180, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_699.mp4
# (125, 176, 176, 3)
# width, height: 650.0 504.0
# Violence/V_786.mp4
# (165, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_298.mp4
# (171, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_626.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_621.mp4
# (185, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_368.mp4
# (153, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_673.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_446.mp4
# (114, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_426.mp4
# (132, 176, 176, 3)
# width, height: 136.0 240.0
# Violence/V_890.mp4
# (133, 176, 176, 3)
# width, height: 1080.0 1920.0
# Violence/V_4.mp4
# (151, 176, 176, 3)
# width, height: 204.0 360.0
# Violence/V_112.mp4
# (132, 176, 176, 3)
# width, height: 728.0 720.0
# Violence/V_280.mp4
# (177, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_10.mp4
# (96, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_132.mp4
# (177, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_36.mp4
# (140, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_542.mp4
# (185, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_320.mp4
# (162, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_554.mp4
# (185, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_905.mp4
# (135, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_740.mp4
# (115, 176, 176, 3)
# width, height: 288.0 360.0
# Violence/V_900.mp4
# (126, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_167.mp4
# (84, 176, 176, 3)
# width, height: 288.0 360.0
# Violence/V_919.mp4
# (126, 176, 176, 3)
# width, height: 1070.0 548.0
# Violence/V_811.mp4
# (123, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_556.mp4
# (185, 176, 176, 3)
# width, height: 282.0 260.0
# Violence/V_258.mp4
# (159, 176, 176, 3)
# width, height: 726.0 620.0
# Violence/V_857.mp4
# (132, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_279.mp4
# (177, 176, 176, 3)
# width, height: 716.0 720.0
# Violence/V_788.mp4
# (132, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_917.mp4
# (112, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_362.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_583.mp4
# (185, 176, 176, 3)
# width, height: 410.0 652.0
# Violence/V_12.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_723.mp4
# (115, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_288.mp4
# (129, 176, 176, 3)
# width, height: 488.0 720.0
# Violence/V_480.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_574.mp4
# (185, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_129.mp4
# (177, 176, 176, 3)
# width, height: 288.0 360.0
# Violence/V_934.mp4
# (135, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_457.mp4
# (132, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_645.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_367.mp4
# (138, 176, 176, 3)
# width, height: 714.0 720.0
# Violence/V_862.mp4
# (117, 176, 176, 3)
# width, height: 398.0 720.0
# Violence/V_70.mp4
# (147, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_352.mp4
# (147, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_944.mp4
# (126, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_949.mp4
# (123, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_644.mp4
# (150, 176, 176, 3)
# width, height: 194.0 298.0
# Violence/V_962.mp4
# (141, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_94.mp4
# (120, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_757.mp4
# (114, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_357.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_573.mp4
# (185, 176, 176, 3)
# width, height: 352.0 600.0
# Violence/V_825.mp4
# (183, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_304.mp4
# (156, 176, 176, 3)
# width, height: 576.0 712.0
# Violence/V_491.mp4
# (132, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_123.mp4
# (177, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_435.mp4
# (135, 176, 176, 3)
# width, height: 822.0 714.0
# Violence/V_836.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_383.mp4
# (78, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_602.mp4
# (185, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_315.mp4
# (168, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_232.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_563.mp4
# (185, 176, 176, 3)
# width, height: 396.0 720.0
# Violence/V_474.mp4
# (141, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_693.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_277.mp4
# (162, 176, 176, 3)
# width, height: 492.0 224.0
# Violence/V_625.mp4
# (100, 176, 176, 3)
# width, height: 404.0 716.0
# Violence/V_391.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_84.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_730.mp4
# (115, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_953.mp4
# (186, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_562.mp4
# (185, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_877.mp4
# (150, 176, 176, 3)
# width, height: 720.0 720.0
# Violence/V_851.mp4
# (162, 176, 176, 3)
# width, height: 424.0 360.0
# Violence/V_889.mp4
# (132, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_421.mp4
# (159, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_633.mp4
# (150, 176, 176, 3)
# width, height: 406.0 614.0
# Violence/V_808.mp4
# (174, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_268.mp4
# (147, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_158.mp4
# (94, 176, 176, 3)
# width, height: 640.0 352.0
# Violence/V_418.mp4
# (111, 176, 176, 3)
# width, height: 406.0 530.0
# Violence/V_818.mp4
# (123, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_910.mp4
# (131, 176, 176, 3)
# width, height: 424.0 360.0
# Violence/V_927.mp4
# (132, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_947.mp4
# (138, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_396.mp4
# (153, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_753.mp4
# (144, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_455.mp4
# (135, 176, 176, 3)
# width, height: 206.0 360.0
# Violence/V_515.mp4
# (114, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_452.mp4
# (141, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_379.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_710.mp4
# (125, 176, 176, 3)
# width, height: 716.0 720.0
# Violence/V_769.mp4
# (177, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_928.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_513.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_569.mp4
# (185, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_667.mp4
# (125, 176, 176, 3)
# width, height: 406.0 406.0
# Violence/V_54.mp4
# (153, 176, 176, 3)
# width, height: 440.0 360.0
# Violence/V_274.mp4
# (92, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_329.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_722.mp4
# (115, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_765.mp4
# (129, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_618.mp4
# (185, 176, 176, 3)
# width, height: 410.0 720.0
# Violence/V_24.mp4
# (210, 176, 176, 3)
# width, height: 240.0 320.0
# Violence/V_65.mp4
# (123, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_451.mp4
# (120, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_971.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_718.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_423.mp4
# (132, 176, 176, 3)
# width, height: 728.0 714.0
# Violence/V_833.mp4
# (153, 176, 176, 3)
# width, height: 406.0 406.0
# Violence/V_46.mp4
# (90, 176, 176, 3)
# width, height: 204.0 360.0
# Violence/V_181.mp4
# (111, 176, 176, 3)
# width, height: 424.0 360.0
# Violence/V_924.mp4
# (144, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_539.mp4
# (185, 176, 176, 3)
# width, height: 854.0 480.0
# Violence/V_504.mp4
# (161, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_324.mp4
# (171, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_687.mp4
# (125, 176, 176, 3)
# width, height: 402.0 546.0
# Violence/V_791.mp4
# (122, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_701.mp4
# (125, 176, 176, 3)
# width, height: 438.0 452.0
# Violence/V_214.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_672.mp4
# (125, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_991.mp4
# (150, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_406.mp4
# (114, 176, 176, 3)
# width, height: 640.0 354.0
# Violence/V_376.mp4
# (150, 176, 176, 3)
# width, height: 438.0 720.0
# Violence/V_220.mp4
# (162, 176, 176, 3)
# width, height: 204.0 360.0
# Violence/V_178.mp4
# (144, 176, 176, 3)
# width, height: 404.0 716.0
# Violence/V_393.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_526.mp4
# (185, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_982.mp4
# (150, 176, 176, 3)
# width, height: 714.0 720.0
# Violence/V_864.mp4
# (123, 176, 176, 3)
# width, height: 288.0 360.0
# Violence/V_901.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_436.mp4
# (132, 176, 176, 3)
# width, height: 338.0 720.0
# Violence/V_259.mp4
# (138, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_121.mp4
# (150, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_412.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_548.mp4
# (185, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_525.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_654.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_726.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_143.mp4
# (177, 176, 176, 3)
# width, height: 1280.0 574.0
# Violence/V_289.mp4
# (141, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_441.mp4
# (111, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_894.mp4
# (139, 176, 176, 3)
# width, height: 442.0 720.0
# Violence/V_254.mp4
# (162, 176, 176, 3)
# width, height: 402.0 720.0
# Violence/V_230.mp4
# (153, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_476.mp4
# (150, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_964.mp4
# (150, 176, 176, 3)
# width, height: 402.0 720.0
# Violence/V_231.mp4
# (153, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_977.mp4
# (150, 176, 176, 3)
# width, height: 1070.0 720.0
# Violence/V_17.mp4
# (192, 176, 176, 3)
# width, height: 1280.0 546.0
# Violence/V_797.mp4
# (122, 176, 176, 3)
# width, height: 960.0 720.0
# Violence/V_370.mp4
# (128, 176, 176, 3)
# width, height: 260.0 360.0
# Violence/V_995.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_571.mp4
# (185, 176, 176, 3)
# width, height: 474.0 302.0
# Violence/V_796.mp4
# (119, 176, 176, 3)
# width, height: 1280.0 570.0
# Violence/V_306.mp4
# (162, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_661.mp4
# (125, 176, 176, 3)
# width, height: 406.0 700.0
# Violence/V_819.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_603.mp4
# (185, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_557.mp4
# (185, 176, 176, 3)
# width, height: 726.0 650.0
# Violence/V_855.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_543.mp4
# (185, 176, 176, 3)
# width, height: 402.0 720.0
# Violence/V_205.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_528.mp4
# (185, 176, 176, 3)
# width, height: 408.0 534.0
# Violence/V_228.mp4
# (153, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_124.mp4
# (177, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_918.mp4
# (112, 176, 176, 3)
# width, height: 438.0 452.0
# Violence/V_207.mp4
# (156, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_643.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_153.mp4
# (177, 176, 176, 3)
# width, height: 228.0 296.0
# Violence/V_883.mp4
# (162, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_613.mp4
# (185, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_102.mp4
# (153, 176, 176, 3)
# width, height: 288.0 360.0
# Violence/V_932.mp4
# (153, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_674.mp4
# (125, 176, 176, 3)
# width, height: 592.0 712.0
# Violence/V_494.mp4
# (132, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_755.mp4
# (126, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_272.mp4
# (162, 176, 176, 3)
# width, height: 724.0 720.0
# Violence/V_776.mp4
# (153, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_662.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_612.mp4
# (185, 176, 176, 3)
# width, height: 204.0 360.0
# Violence/V_113.mp4
# (162, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_767.mp4
# (129, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_921.mp4
# (107, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_558.mp4
# (185, 176, 176, 3)
# ...
# width, height: 224.0 224.0
# NonViolence/NV_245.mp4
# (125, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_841.mp4
# (113, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_799.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_103.mp4
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_90.mp4
# (138, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_844.mp4
# (137, 176, 176, 3)
# width, height: 1920.0 1080.0
# NonViolence/NV_354.mp4
# (36, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_641.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_511.mp4
# (145, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_300.mp4
# (159, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_485.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_987.mp4
# (145, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_745.mp4
# (134, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_698.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_759.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_281.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_615.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_122.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_653.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_564.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_312.mp4
# (108, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_3.mp4
# (128, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_184.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_125.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_127.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_488.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_642.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_179.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_600.mp4
# (63, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_920.mp4
# (145, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_781.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_721.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_192.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_778.mp4
# (115, 176, 176, 3)
# width, height: 854.0 480.0
# NonViolence/NV_226.mp4
# (161, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_303.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# NonViolence/NV_323.mp4
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# NonViolence/NV_351.mp4
# (204, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_782.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_120.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_200.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# NonViolence/NV_688.mp4
# (125, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_936.mp4
# (153, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_761.mp4
# (126, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_764.mp4
# (123, 176, 176, 3)
# width, height: 260.0 360.0
# Violence/V_1000.mp4
# (150, 176, 176, 3)
# width, height: 198.0 360.0
# Violence/V_916.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_243.mp4
# (105, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_5.mp4
# (114, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_937.mp4
# (141, 176, 176, 3)
# width, height: 260.0 360.0
# Violence/V_998.mp4
# (150, 176, 176, 3)
# width, height: 194.0 298.0
# Violence/V_959.mp4
# (126, 176, 176, 3)
# width, height: 240.0 320.0
# Violence/V_69.mp4
# (105, 176, 176, 3)
# width, height: 406.0 614.0
# Violence/V_807.mp4
# (144, 176, 176, 3)
# width, height: 136.0 240.0
# Violence/V_908.mp4
# (141, 176, 176, 3)
# width, height: 394.0 548.0
# Violence/V_790.mp4
# (136, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_941.mp4
# (143, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_727.mp4
# (115, 176, 176, 3)
# width, height: 402.0 720.0
# Violence/V_203.mp4
# (153, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_763.mp4
# (129, 176, 176, 3)
# width, height: 926.0 472.0
# Violence/V_846.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_108.mp4
# (120, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_608.mp4
# (185, 176, 176, 3)
# width, height: 1280.0 542.0
# Violence/V_33.mp4
# (143, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_586.mp4
# (185, 176, 176, 3)
# width, height: 406.0 406.0
# Violence/V_53.mp4
# (111, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_966.mp4
# (150, 176, 176, 3)
# width, height: 406.0 406.0
# Violence/V_45.mp4
# (99, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_453.mp4
# (120, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_157.mp4
# (90, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_648.mp4
# (125, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_96.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_725.mp4
# (115, 176, 176, 3)
# width, height: 640.0 644.0
# Violence/V_829.mp4
# (150, 176, 176, 3)
# width, height: 194.0 298.0
# Violence/V_961.mp4
# (135, 176, 176, 3)
# width, height: 804.0 546.0
# Violence/V_677.mp4
# (122, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_239.mp4
# (156, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_2.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_141.mp4
# (177, 176, 176, 3)
# width, height: 804.0 546.0
# Violence/V_795.mp4
# (144, 176, 176, 3)
# width, height: 204.0 360.0
# Violence/V_182.mp4
# (111, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_553.mp4
# (185, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_568.mp4
# (185, 176, 176, 3)
# width, height: 408.0 720.0
# Violence/V_225.mp4
# (165, 176, 176, 3)
# width, height: 136.0 240.0
# Violence/V_892.mp4
# (139, 176, 176, 3)
# width, height: 198.0 360.0
# Violence/V_931.mp4
# (162, 176, 176, 3)
# width, height: 396.0 720.0
# Violence/V_466.mp4
# (165, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_636.mp4
# (150, 176, 176, 3)
# width, height: 406.0 712.0
# Violence/V_493.mp4
# (108, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_637.mp4
# (150, 176, 176, 3)
# width, height: 650.0 504.0
# Violence/V_787.mp4
# (156, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_340.mp4
# (117, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_595.mp4
# (185, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_976.mp4
# (150, 176, 176, 3)
# width, height: 650.0 482.0
# Violence/V_785.mp4
# (162, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_325.mp4
# (165, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_992.mp4
# (150, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_342.mp4
# (153, 176, 176, 3)
# width, height: 410.0 720.0
# Violence/V_23.mp4
# (126, 176, 176, 3)
# width, height: 452.0 360.0
# Violence/V_520.mp4
# (135, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_691.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_463.mp4
# (189, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_559.mp4
# (185, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_702.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_294.mp4
# (144, 176, 176, 3)
# width, height: 404.0 716.0
# Violence/V_389.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_760.mp4
# (123, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_620.mp4
# (185, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_293.mp4
# (141, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_159.mp4
# (76, 176, 176, 3)
# width, height: 484.0 360.0
# Violence/V_345.mp4
# (117, 176, 176, 3)
# width, height: 396.0 720.0
# Violence/V_468.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_39.mp4
# (140, 176, 176, 3)
# width, height: 834.0 714.0
# Violence/V_840.mp4
# (150, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_983.mp4
# (150, 176, 176, 3)
# width, height: 726.0 650.0
# Violence/V_856.mp4
# (117, 176, 176, 3)
# width, height: 1280.0 602.0
# Violence/V_309.mp4
# (138, 176, 176, 3)
# width, height: 576.0 720.0
# Violence/V_15.mp4
# (108, 176, 176, 3)
# width, height: 406.0 536.0
# Violence/V_813.mp4
# (168, 176, 176, 3)
# width, height: 406.0 664.0
# Violence/V_806.mp4
# (153, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_876.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_398.mp4
# (4109, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_73.mp4
# (150, 176, 176, 3)
# width, height: 654.0 650.0
# Violence/V_30.mp4
# (105, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_611.mp4
# (185, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_732.mp4
# (115, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_689.mp4
# (125, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_347.mp4
# (189, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_448.mp4
# (129, 176, 176, 3)
# width, height: 406.0 360.0
# Violence/V_524.mp4
# (150, 176, 176, 3)
# width, height: 442.0 720.0
# Violence/V_249.mp4
# (108, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_994.mp4
# (150, 176, 176, 3)
# width, height: 724.0 720.0
# Violence/V_770.mp4
# (138, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_590.mp4
# (185, 176, 176, 3)
# width, height: 410.0 720.0
# Violence/V_256.mp4
# (150, 176, 176, 3)
# width, height: 198.0 360.0
# Violence/V_915.mp4
# (141, 176, 176, 3)
# width, height: 240.0 320.0
# Violence/V_66.mp4
# (105, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_164.mp4
# (106, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_696.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_728.mp4
# (115, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_972.mp4
# (87, 176, 176, 3)
# width, height: 484.0 360.0
# Violence/V_344.mp4
# (117, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_716.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_291.mp4
# (144, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_425.mp4
# (153, 176, 176, 3)
# width, height: 406.0 406.0
# Violence/V_44.mp4
# (129, 176, 176, 3)
# width, height: 442.0 720.0
# Violence/V_248.mp4
# (114, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_434.mp4
# (117, 176, 176, 3)
# width, height: 726.0 670.0
# Violence/V_868.mp4
# (129, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_684.mp4
# (125, 176, 176, 3)
# width, height: 206.0 360.0
# Violence/V_516.mp4
# (123, 176, 176, 3)
# width, height: 194.0 298.0
# Violence/V_958.mp4
# (126, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_951.mp4
# (147, 176, 176, 3)
# width, height: 286.0 360.0
# Violence/V_191.mp4
# (165, 176, 176, 3)
# width, height: 288.0 360.0
# Violence/V_898.mp4
# (129, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_98.mp4
# (150, 176, 176, 3)
# width, height: 136.0 240.0
# Violence/V_887.mp4
# (120, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_171.mp4
# (62, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_365.mp4
# (150, 176, 176, 3)
# width, height: 406.0 536.0
# Violence/V_810.mp4
# (162, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_308.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_708.mp4
# (125, 176, 176, 3)
# width, height: 854.0 540.0
# Violence/V_14.mp4
# (180, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_162.mp4
# (108, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_748.mp4
# (150, 176, 176, 3)
# width, height: 440.0 360.0
# Violence/V_275.mp4
# (92, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_630.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_431.mp4
# (129, 176, 176, 3)
# width, height: 136.0 240.0
# Violence/V_893.mp4
# (107, 176, 176, 3)
# width, height: 198.0 360.0
# Violence/V_914.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_669.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_678.mp4
# (125, 176, 176, 3)
# width, height: 726.0 670.0
# Violence/V_863.mp4
# (117, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_369.mp4
# (140, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_607.mp4
# (185, 176, 176, 3)
# width, height: 320.0 240.0
# Violence/V_170.mp4
# (110, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_447.mp4
# (129, 176, 176, 3)
# width, height: 438.0 452.0
# Violence/V_212.mp4
# (156, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_593.mp4
# (185, 176, 176, 3)
# width, height: 452.0 360.0
# Violence/V_521.mp4
# (120, 176, 176, 3)
# width, height: 724.0 720.0
# Violence/V_771.mp4
# (162, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_138.mp4
# (177, 176, 176, 3)
# width, height: 644.0 714.0
# Violence/V_842.mp4
# (132, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_341.mp4
# (159, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_655.mp4
# (125, 176, 176, 3)
# width, height: 640.0 352.0
# Violence/V_415.mp4
# (96, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_88.mp4
# (138, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_429.mp4
# (120, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_188.mp4
# (168, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_449.mp4
# (141, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_183.mp4
# (168, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_990.mp4
# (150, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_408.mp4
# (105, 176, 176, 3)
# width, height: 416.0 548.0
# Violence/V_801.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 574.0
# Violence/V_297.mp4
# (141, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_241.mp4
# (144, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_967.mp4
# (150, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_411.mp4
# (111, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_984.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_741.mp4
# (115, 176, 176, 3)
# width, height: 442.0 720.0
# Violence/V_245.mp4
# (105, 176, 176, 3)
# width, height: 400.0 510.0
# Violence/V_841.mp4
# (150, 176, 176, 3)
# width, height: 804.0 546.0
# Violence/V_799.mp4
# (117, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_103.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_90.mp4
# (150, 176, 176, 3)
# width, height: 670.0 692.0
# Violence/V_844.mp4
# (156, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_354.mp4
# (141, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_641.mp4
# (150, 176, 176, 3)
# width, height: 406.0 440.0
# Violence/V_511.mp4
# (147, 176, 176, 3)
# width, height: 1280.0 548.0
# Violence/V_300.mp4
# (195, 176, 176, 3)
# width, height: 428.0 606.0
# Violence/V_485.mp4
# (153, 176, 176, 3)
# width, height: 292.0 360.0
# Violence/V_987.mp4
# (150, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_745.mp4
# (165, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_698.mp4
# (125, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_759.mp4
# (117, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_281.mp4
# (162, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_615.mp4
# (185, 176, 176, 3)
# width, height: 210.0 358.0
# Violence/V_122.mp4
# (150, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_653.mp4
# (125, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_564.mp4
# (185, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_312.mp4
# (129, 176, 176, 3)
# width, height: 1080.0 1920.0
# Violence/V_3.mp4
# (174, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_184.mp4
# (168, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_125.mp4
# (177, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_127.mp4
# (177, 176, 176, 3)
# width, height: 576.0 712.0
# Violence/V_488.mp4
# (171, 176, 176, 3)
# width, height: 1920.0 1080.0
# Violence/V_642.mp4
# (150, 176, 176, 3)
# width, height: 204.0 360.0
# Violence/V_179.mp4
# (141, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_600.mp4
# (185, 176, 176, 3)
# width, height: 202.0 360.0
# Violence/V_920.mp4
# (112, 176, 176, 3)
# width, height: 716.0 720.0
# Violence/V_781.mp4
# (147, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_721.mp4
# (115, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_192.mp4
# (117, 176, 176, 3)
# width, height: 406.0 720.0
# Violence/V_778.mp4
# (144, 176, 176, 3)
# width, height: 408.0 534.0
# Violence/V_226.mp4
# (153, 176, 176, 3)
# width, height: 1280.0 574.0
# Violence/V_303.mp4
# (183, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_323.mp4
# (153, 176, 176, 3)
# width, height: 360.0 360.0
# Violence/V_351.mp4
# (138, 176, 176, 3)
# width, height: 716.0 720.0
# Violence/V_782.mp4
# (156, 176, 176, 3)
# width, height: 1280.0 720.0
# Violence/V_120.mp4
# (147, 176, 176, 3)
# width, height: 640.0 360.0
# Violence/V_200.mp4
# (168, 176, 176, 3)
# width, height: 224.0 224.0
# Violence/V_688.mp4
# (125, 176, 176, 3)
# Frame features in train set: (20, 1024)
# Frame masks in test set: (20, 1024)

# %%
from numpy import save

save('rlvs_train_data.npy', train_data)
save('rlvs_train_labels.npy', train_labels)
save('rlvs_test_data.npy', test_data)
save('rlvs_test_labels.npy', test_labels)

# %%
train_data, train_labels = np.load("rlvs_train_data.npy"), np.load("rlvs_train_labels.npy")
test_data, test_labels = np.load("rlvs_test_data.npy"), np.load("rlvs_test_labels.npy")

# %%
print(f"Frame features in train set: {train_data.shape}")
print(f"Frame features in train label set: {train_labels.shape}")
print(f"Frame features in test set: {test_data.shape}")
print(f"Frame features in test label set: {test_labels.shape}")
# Out:
# Frame features in train set: (1600, 20, 1024)
# Frame features in train label set: (1600, 1)
# Frame features in test set: (400, 20, 1024)
# Frame features in test label set: (400, 1)

# %% [markdown]
# Calling `prepare_all_videos()` on `train_df` and `test_df` takes ~20 minutes to
# complete. For this reason, to save time, here we download already preprocessed NumPy arrays:

# %% [markdown]
# ## Building the Transformer-based model
#
# We will be building on top of the code shared in
# [this book chapter](https://livebook.manning.com/book/deep-learning-with-python-second-edition/chapter-11) of
# [Deep Learning with Python (Second ed.)](https://www.manning.com/books/deep-learning-with-python)
# by François Chollet.
#
# First, self-attention layers that form the basic blocks of a Transformer are
# order-agnostic. Since videos are ordered sequences of frames, we need our
# Transformer model to take into account order information.
# We do this via **positional encoding**.
# We simply embed the positions of the frames present inside videos with an
# [`Embedding` layer](https://keras.io/api/layers/core_layers/embedding). We then
# add these positional embeddings to the precomputed CNN feature maps.

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %% [markdown]
# Now, we can create a subclassed layer for the Transformer.

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
def get_compiled_model():
    sequence_length = MAX_SEQ_LENGTH
    embed_dim = NUM_FEATURES
    dense_dim = 64
    num_heads = 8
    classes = len(label_processor.get_vocabulary())

    inputs = keras.Input(shape=(None, None))
    x = PositionalEmbedding(
        sequence_length, embed_dim, name="frame_position_embedding"
    )(inputs)
    x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
    x = layers.Bidirectional(layers.LSTM(1024,return_sequences=True))(x)
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(classes, activation="softmax")(x)
    model = keras.Model(inputs, outputs)

    model.compile(
        optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
model = get_compiled_model()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, None, None)]      0
# _________________________________________________________________
# frame_position_embedding (Po (None, None, 1024)        20480
# _________________________________________________________________
# transformer_layer (Transform (None, None, 1024)        33716288
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 2048)        16785408
# _________________________________________________________________
# global_max_pooling1d (Global (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 50,526,274
# Trainable params: 50,526,274
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Utility functions for training

# %%
def run_experiment():
    filepath = "/tmp/video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    
    history = model.fit(
        train_data,
        train_labels,
        validation_split=0.15,
        epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    model.load_weights(filepath)
    _, accuracy = model.evaluate(test_data, test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return model,history

# %% [markdown]
# ## Model training and inference

# %%
trained_model,history = run_experiment()
# Out:
# Epoch 1/100
# 43/43 [==============================] - 18s 194ms/step - loss: 0.9822 - accuracy: 0.5353 - val_loss: 0.5042 - val_accuracy: 1.0000
#
# Epoch 00001: val_loss improved from inf to 0.50422, saving model to /tmp/video_classifier
# Epoch 2/100
# 43/43 [==============================] - 7s 167ms/step - loss: 0.7125 - accuracy: 0.5507 - val_loss: 0.8985 - val_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 0.50422
# Epoch 3/100
# 43/43 [==============================] - 7s 167ms/step - loss: 0.5114 - accuracy: 0.7463 - val_loss: 0.3141 - val_accuracy: 0.8708
#
# Epoch 00003: val_loss improved from 0.50422 to 0.31409, saving model to /tmp/video_classifier
# Epoch 4/100
# 43/43 [==============================] - 7s 168ms/step - loss: 0.2637 - accuracy: 0.8904 - val_loss: 0.6750 - val_accuracy: 0.7167
#
# Epoch 00004: val_loss did not improve from 0.31409
# Epoch 5/100
# 43/43 [==============================] - 7s 169ms/step - loss: 0.2435 - accuracy: 0.9029 - val_loss: 0.0797 - val_accuracy: 0.9708
#
# Epoch 00005: val_loss improved from 0.31409 to 0.07973, saving model to /tmp/video_classifier
# Epoch 6/100
# 43/43 [==============================] - 7s 169ms/step - loss: 0.1993 - accuracy: 0.9235 - val_loss: 0.2263 - val_accuracy: 0.9083
#
# Epoch 00006: val_loss did not improve from 0.07973
# Epoch 7/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1631 - accuracy: 0.9471 - val_loss: 0.4413 - val_accuracy: 0.7875
#
# Epoch 00007: val_loss did not improve from 0.07973
# Epoch 8/100
# 43/43 [==============================] - 7s 169ms/step - loss: 0.1190 - accuracy: 0.9588 - val_loss: 0.2722 - val_accuracy: 0.8708
#
# Epoch 00008: val_loss did not improve from 0.07973
# Epoch 9/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1515 - accuracy: 0.9412 - val_loss: 0.1825 - val_accuracy: 0.9250
#
# Epoch 00009: val_loss did not improve from 0.07973
# Epoch 10/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1553 - accuracy: 0.9426 - val_loss: 0.7192 - val_accuracy: 0.8167
#
# Epoch 00010: val_loss did not improve from 0.07973
# Epoch 11/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1179 - accuracy: 0.9522 - val_loss: 0.6463 - val_accuracy: 0.7958
#
# Epoch 00011: val_loss did not improve from 0.07973
# Epoch 12/100
# 43/43 [==============================] - 7s 172ms/step - loss: 0.1051 - accuracy: 0.9581 - val_loss: 0.4864 - val_accuracy: 0.8292
#
# Epoch 00012: val_loss did not improve from 0.07973
# Epoch 13/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0784 - accuracy: 0.9669 - val_loss: 0.3785 - val_accuracy: 0.9208
#
# Epoch 00013: val_loss did not improve from 0.07973
# Epoch 14/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0855 - accuracy: 0.9772 - val_loss: 0.5093 - val_accuracy: 0.8833
#
# Epoch 00014: val_loss did not improve from 0.07973
# Epoch 15/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0666 - accuracy: 0.9787 - val_loss: 0.6284 - val_accuracy: 0.8500
#
# Epoch 00015: val_loss did not improve from 0.07973
# Epoch 16/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0918 - accuracy: 0.9699 - val_loss: 0.2006 - val_accuracy: 0.9208
#
# Epoch 00016: val_loss did not improve from 0.07973
# Epoch 17/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0776 - accuracy: 0.9691 - val_loss: 0.4804 - val_accuracy: 0.9000
#
# Epoch 00017: val_loss did not improve from 0.07973
# Epoch 18/100
# 43/43 [==============================] - 7s 172ms/step - loss: 0.0736 - accuracy: 0.9713 - val_loss: 0.2634 - val_accuracy: 0.9167
#
# Epoch 00018: val_loss did not improve from 0.07973
# Epoch 19/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0377 - accuracy: 0.9868 - val_loss: 0.6598 - val_accuracy: 0.8375
#
# Epoch 00019: val_loss did not improve from 0.07973
# Epoch 20/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0218 - accuracy: 0.9956 - val_loss: 0.8837 - val_accuracy: 0.8458
#
# Epoch 00020: val_loss did not improve from 0.07973
# Epoch 21/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0183 - accuracy: 0.9949 - val_loss: 0.7578 - val_accuracy: 0.8708
#
# Epoch 00021: val_loss did not improve from 0.07973
# Epoch 22/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0272 - accuracy: 0.9904 - val_loss: 1.5108 - val_accuracy: 0.7625
#
# Epoch 00022: val_loss did not improve from 0.07973
# Epoch 23/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1097 - accuracy: 0.9596 - val_loss: 0.9305 - val_accuracy: 0.7542
#
# Epoch 00023: val_loss did not improve from 0.07973
# Epoch 24/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0572 - accuracy: 0.9831 - val_loss: 0.3117 - val_accuracy: 0.9042
#
# Epoch 00024: val_loss did not improve from 0.07973
# Epoch 25/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0439 - accuracy: 0.9853 - val_loss: 0.3435 - val_accuracy: 0.9250
#
# Epoch 00025: val_loss did not improve from 0.07973
# Epoch 26/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0399 - accuracy: 0.9868 - val_loss: 0.9072 - val_accuracy: 0.8458
#
# Epoch 00026: val_loss did not improve from 0.07973
# Epoch 27/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0458 - accuracy: 0.9853 - val_loss: 0.8147 - val_accuracy: 0.8333
#
# Epoch 00027: val_loss did not improve from 0.07973
# Epoch 28/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0611 - accuracy: 0.9757 - val_loss: 0.2966 - val_accuracy: 0.9125
#
# Epoch 00028: val_loss did not improve from 0.07973
# Epoch 29/100
# 43/43 [==============================] - 7s 172ms/step - loss: 0.0560 - accuracy: 0.9801 - val_loss: 0.4690 - val_accuracy: 0.8958
#
# Epoch 00029: val_loss did not improve from 0.07973
# Epoch 30/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0559 - accuracy: 0.9787 - val_loss: 0.4223 - val_accuracy: 0.8750
#
# Epoch 00030: val_loss did not improve from 0.07973
# Epoch 31/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0363 - accuracy: 0.9875 - val_loss: 0.7070 - val_accuracy: 0.8792
#
# Epoch 00031: val_loss did not improve from 0.07973
# Epoch 32/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0529 - accuracy: 0.9868 - val_loss: 0.2984 - val_accuracy: 0.9208
#
# Epoch 00032: val_loss did not improve from 0.07973
# Epoch 33/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0426 - accuracy: 0.9838 - val_loss: 0.5406 - val_accuracy: 0.8458
#
# Epoch 00033: val_loss did not improve from 0.07973
# Epoch 34/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0352 - accuracy: 0.9860 - val_loss: 0.4365 - val_accuracy: 0.8875
#
# Epoch 00034: val_loss did not improve from 0.07973
# Epoch 35/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0829 - accuracy: 0.9676 - val_loss: 0.4715 - val_accuracy: 0.8625
#
# Epoch 00035: val_loss did not improve from 0.07973
# Epoch 36/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0466 - accuracy: 0.9801 - val_loss: 0.5265 - val_accuracy: 0.8750
#
# Epoch 00036: val_loss did not improve from 0.07973
# Epoch 37/100
# 43/43 [==============================] - 7s 172ms/step - loss: 0.0294 - accuracy: 0.9912 - val_loss: 0.6496 - val_accuracy: 0.8833
#
# Epoch 00037: val_loss did not improve from 0.07973
# Epoch 38/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0472 - accuracy: 0.9779 - val_loss: 0.6774 - val_accuracy: 0.8417
#
# Epoch 00038: val_loss did not improve from 0.07973
# Epoch 39/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0542 - accuracy: 0.9809 - val_loss: 0.5985 - val_accuracy: 0.8542
#
# Epoch 00039: val_loss did not improve from 0.07973
# Epoch 40/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0186 - accuracy: 0.9949 - val_loss: 0.6618 - val_accuracy: 0.8875
#
# Epoch 00040: val_loss did not improve from 0.07973
# Epoch 41/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0700 - accuracy: 0.9779 - val_loss: 0.4884 - val_accuracy: 0.8500
#
# Epoch 00041: val_loss did not improve from 0.07973
# Epoch 42/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0245 - accuracy: 0.9904 - val_loss: 0.6185 - val_accuracy: 0.8792
#
# Epoch 00042: val_loss did not improve from 0.07973
# Epoch 43/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0151 - accuracy: 0.9949 - val_loss: 1.7579 - val_accuracy: 0.7625
#
# Epoch 00043: val_loss did not improve from 0.07973
# Epoch 44/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1119 - accuracy: 0.9662 - val_loss: 0.2357 - val_accuracy: 0.9000
#
# Epoch 00044: val_loss did not improve from 0.07973
# Epoch 45/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1319 - accuracy: 0.9493 - val_loss: 0.7191 - val_accuracy: 0.8333
#
# Epoch 00045: val_loss did not improve from 0.07973
# Epoch 46/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0387 - accuracy: 0.9868 - val_loss: 0.8358 - val_accuracy: 0.8125
#
# Epoch 00046: val_loss did not improve from 0.07973
# Epoch 47/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0581 - accuracy: 0.9735 - val_loss: 0.9528 - val_accuracy: 0.8083
#
# Epoch 00047: val_loss did not improve from 0.07973
# Epoch 48/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0367 - accuracy: 0.9875 - val_loss: 2.0709 - val_accuracy: 0.7250
#
# Epoch 00048: val_loss did not improve from 0.07973
# Epoch 49/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0469 - accuracy: 0.9816 - val_loss: 1.3463 - val_accuracy: 0.7583
#
# Epoch 00049: val_loss did not improve from 0.07973
# Epoch 50/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0204 - accuracy: 0.9919 - val_loss: 1.2541 - val_accuracy: 0.8458
#
# Epoch 00050: val_loss did not improve from 0.07973
# Epoch 51/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 1.3665 - val_accuracy: 0.8375
#
# Epoch 00051: val_loss did not improve from 0.07973
# Epoch 52/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0318 - accuracy: 0.9890 - val_loss: 1.6947 - val_accuracy: 0.8125
#
# Epoch 00052: val_loss did not improve from 0.07973
# Epoch 53/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0284 - accuracy: 0.9890 - val_loss: 2.2527 - val_accuracy: 0.7458
#
# Epoch 00053: val_loss did not improve from 0.07973
# Epoch 54/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0337 - accuracy: 0.9890 - val_loss: 1.3199 - val_accuracy: 0.8167
#
# Epoch 00054: val_loss did not improve from 0.07973
# Epoch 55/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0287 - accuracy: 0.9904 - val_loss: 0.6094 - val_accuracy: 0.8708
#
# Epoch 00055: val_loss did not improve from 0.07973
# Epoch 56/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0273 - accuracy: 0.9904 - val_loss: 1.2990 - val_accuracy: 0.7833
#
# Epoch 00056: val_loss did not improve from 0.07973
# Epoch 57/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0163 - accuracy: 0.9963 - val_loss: 1.8175 - val_accuracy: 0.7583
#
# Epoch 00057: val_loss did not improve from 0.07973
# Epoch 58/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1705 - accuracy: 0.9382 - val_loss: 0.5420 - val_accuracy: 0.8333
#
# Epoch 00058: val_loss did not improve from 0.07973
# Epoch 59/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0356 - accuracy: 0.9875 - val_loss: 0.9010 - val_accuracy: 0.7875
#
# Epoch 00059: val_loss did not improve from 0.07973
# Epoch 60/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0174 - accuracy: 0.9919 - val_loss: 1.0952 - val_accuracy: 0.8667
#
# Epoch 00060: val_loss did not improve from 0.07973
# Epoch 61/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0517 - accuracy: 0.9794 - val_loss: 0.2774 - val_accuracy: 0.9458
#
# Epoch 00061: val_loss did not improve from 0.07973
# Epoch 62/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0589 - accuracy: 0.9787 - val_loss: 1.2880 - val_accuracy: 0.8042
#
# Epoch 00062: val_loss did not improve from 0.07973
# Epoch 63/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0247 - accuracy: 0.9919 - val_loss: 0.7259 - val_accuracy: 0.8792
#
# Epoch 00063: val_loss did not improve from 0.07973
# Epoch 64/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0251 - accuracy: 0.9897 - val_loss: 1.2445 - val_accuracy: 0.8208
#
# Epoch 00064: val_loss did not improve from 0.07973
# Epoch 65/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0298 - accuracy: 0.9926 - val_loss: 1.1164 - val_accuracy: 0.8583
#
# Epoch 00065: val_loss did not improve from 0.07973
# Epoch 66/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0508 - accuracy: 0.9868 - val_loss: 0.4831 - val_accuracy: 0.8250
#
# Epoch 00066: val_loss did not improve from 0.07973
# Epoch 67/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.6678 - val_accuracy: 0.8458
#
# Epoch 00067: val_loss did not improve from 0.07973
# Epoch 68/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0122 - accuracy: 0.9956 - val_loss: 1.6960 - val_accuracy: 0.6917
#
# Epoch 00068: val_loss did not improve from 0.07973
# Epoch 69/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0245 - accuracy: 0.9890 - val_loss: 0.6518 - val_accuracy: 0.8708
#
# Epoch 00069: val_loss did not improve from 0.07973
# Epoch 70/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.7139 - val_accuracy: 0.8792
#
# Epoch 00070: val_loss did not improve from 0.07973
# Epoch 71/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 0.6177 - val_accuracy: 0.9042
#
# Epoch 00071: val_loss did not improve from 0.07973
# Epoch 72/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0056 - accuracy: 0.9993 - val_loss: 1.2071 - val_accuracy: 0.8250
#
# Epoch 00072: val_loss did not improve from 0.07973
# Epoch 73/100
# 43/43 [==============================] - 7s 171ms/step - loss: 6.5512e-04 - accuracy: 1.0000 - val_loss: 1.1720 - val_accuracy: 0.8375
#
# Epoch 00073: val_loss did not improve from 0.07973
# Epoch 74/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 0.8026 - val_accuracy: 0.8917
#
# Epoch 00074: val_loss did not improve from 0.07973
# Epoch 75/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0189 - accuracy: 0.9926 - val_loss: 0.8842 - val_accuracy: 0.8333
#
# Epoch 00075: val_loss did not improve from 0.07973
# Epoch 76/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0276 - accuracy: 0.9897 - val_loss: 1.0768 - val_accuracy: 0.8292
#
# Epoch 00076: val_loss did not improve from 0.07973
# Epoch 77/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1915 - accuracy: 0.9412 - val_loss: 0.9917 - val_accuracy: 0.8417
#
# Epoch 00077: val_loss did not improve from 0.07973
# Epoch 78/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 1.5510 - val_accuracy: 0.8167
#
# Epoch 00078: val_loss did not improve from 0.07973
# Epoch 79/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.2217 - accuracy: 0.9324 - val_loss: 0.5751 - val_accuracy: 0.9208
#
# Epoch 00079: val_loss did not improve from 0.07973
# Epoch 80/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1082 - accuracy: 0.9662 - val_loss: 0.9792 - val_accuracy: 0.8375
#
# Epoch 00080: val_loss did not improve from 0.07973
# Epoch 81/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1698 - accuracy: 0.9412 - val_loss: 1.8489 - val_accuracy: 0.6667
#
# Epoch 00081: val_loss did not improve from 0.07973
# Epoch 82/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1380 - accuracy: 0.9515 - val_loss: 1.2788 - val_accuracy: 0.8333
#
# Epoch 00082: val_loss did not improve from 0.07973
# Epoch 83/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1150 - accuracy: 0.9632 - val_loss: 0.7384 - val_accuracy: 0.8833
#
# Epoch 00083: val_loss did not improve from 0.07973
# Epoch 84/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1717 - accuracy: 0.9375 - val_loss: 1.8032 - val_accuracy: 0.7708
#
# Epoch 00084: val_loss did not improve from 0.07973
# Epoch 85/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0691 - accuracy: 0.9713 - val_loss: 1.5767 - val_accuracy: 0.7917
#
# Epoch 00085: val_loss did not improve from 0.07973
# Epoch 86/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1130 - accuracy: 0.9618 - val_loss: 0.6877 - val_accuracy: 0.8875
#
# Epoch 00086: val_loss did not improve from 0.07973
# Epoch 87/100
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0682 - accuracy: 0.9713 - val_loss: 0.8820 - val_accuracy: 0.8208
#
# Epoch 00087: val_loss did not improve from 0.07973
# Epoch 88/100
# 43/43 [==============================] - 7s 170ms/step - loss: 0.0564 - accuracy: 0.9838 - val_loss: 0.8558 - val_accuracy: 0.8417
#
# Epoch 00088: val_loss did not improve from 0.07973
# Epoch 89/100
# 43/43 [==============================] - 7s 169ms/step - loss: 0.0398 - accuracy: 0.9868 - val_loss: 0.6680 - val_accuracy: 0.9042
#
# Epoch 00089: val_loss did not improve from 0.07973
# Epoch 90/100
# 43/43 [==============================] - 7s 168ms/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 1.0638 - val_accuracy: 0.8583
#
# Epoch 00090: val_loss did not improve from 0.07973
# Epoch 91/100
# 43/43 [==============================] - 7s 167ms/step - loss: 0.0582 - accuracy: 0.9809 - val_loss: 0.9590 - val_accuracy: 0.8792
#
# Epoch 00091: val_loss did not improve from 0.07973
# Epoch 92/100
# 43/43 [==============================] - 7s 167ms/step - loss: 0.0364 - accuracy: 0.9824 - val_loss: 1.2877 - val_accuracy: 0.8667
#
# Epoch 00092: val_loss did not improve from 0.07973
# Epoch 93/100
# 43/43 [==============================] - 7s 166ms/step - loss: 0.0417 - accuracy: 0.9853 - val_loss: 0.4209 - val_accuracy: 0.9417
#
# Epoch 00093: val_loss did not improve from 0.07973
# Epoch 94/100
# 43/43 [==============================] - 7s 166ms/step - loss: 0.0421 - accuracy: 0.9816 - val_loss: 0.3852 - val_accuracy: 0.9167
#
# Epoch 00094: val_loss did not improve from 0.07973
# Epoch 95/100
# 43/43 [==============================] - 7s 165ms/step - loss: 0.0568 - accuracy: 0.9765 - val_loss: 0.4350 - val_accuracy: 0.9250
#
# Epoch 00095: val_loss did not improve from 0.07973
# Epoch 96/100
# 43/43 [==============================] - 7s 165ms/step - loss: 0.0980 - accuracy: 0.9699 - val_loss: 1.5173 - val_accuracy: 0.8167
#
# Epoch 00096: val_loss did not improve from 0.07973
# Epoch 97/100
# 43/43 [==============================] - 7s 166ms/step - loss: 0.0991 - accuracy: 0.9618 - val_loss: 0.9383 - val_accuracy: 0.8250
#
# Epoch 00097: val_loss did not improve from 0.07973
# Epoch 98/100
# 43/43 [==============================] - 7s 166ms/step - loss: 0.0548 - accuracy: 0.9824 - val_loss: 0.8805 - val_accuracy: 0.8917
#
# Epoch 00098: val_loss did not improve from 0.07973
# Epoch 99/100
# 43/43 [==============================] - 7s 166ms/step - loss: 0.1169 - accuracy: 0.9559 - val_loss: 1.3287 - val_accuracy: 0.8583
#
# Epoch 00099: val_loss did not improve from 0.07973
# Epoch 100/100
# 43/43 [==============================] - 7s 165ms/step - loss: 0.0538 - accuracy: 0.9824 - val_loss: 1.4861 - val_accuracy: 0.8250
#
# Epoch 00100: val_loss did not improve from 0.07973
# 13/13 [==============================] - 1s 67ms/step - loss: 0.2868 - accuracy: 0.8775
# Test accuracy: 87.75%

# %%
from matplotlib import pyplot

# %%
    pyplot.title('Learning Curves')
    pyplot.xlabel('Epoch')
    pyplot.ylabel('Root Mean Squared Error')
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='val')
    pyplot.legend()
    pyplot.show()

# %% [markdown]
# **Note**: This model has ~4.23 Million parameters, which is way more than the sequence
# model (99918 parameters) we used in the prequel of this example.  This kind of
# Transformer model works best with a larger dataset and a longer pre-training schedule.

# %%
def prepare_single_video(frames):
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    # Pad shorter videos.
    if len(frames) < MAX_SEQ_LENGTH:
        diff = MAX_SEQ_LENGTH - len(frames)
        padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
        frames = np.concatenate(frames, padding)

    frames = frames[None, ...]

    # Extract features from the frames of the current video.
    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            if np.mean(batch[j, :]) > 0.0:
                frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
            else:
                frame_features[i, j, :] = 0.0

    return frame_features


def predict_action(path):
    class_vocab = label_processor.get_vocabulary()

    frames = load_video(os.path.join("rlvs/test/", path))
    frame_features = prepare_single_video(frames)
    probabilities = trained_model.predict(frame_features)[0]

    for i in np.argsort(probabilities)[::-1]:
        print(f"  {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")
    return frames


# This utility is for visualization.
# Referenced from:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def to_gif(images):
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, fps=10)
    return embed.embed_file("animation.gif")


test_video = np.random.choice(test_df["video_name"].values.tolist())
print(f"Test video path: {test_video}")
test_frames = predict_action(test_video)
to_gif(test_frames[:MAX_SEQ_LENGTH])
# Out:
# Test video path: NonViolence/NV_764.mp4
# width, height: 224.0 224.0
#   Violence: 72.42%
#   NonViolence: 27.58%
# <img src="data:image/gif;base64,..."/>

# %% [markdown]
# The performance of our model is far from optimal, because it was trained on a
# small dataset.
